# %%
import EDA
import cslib

# %%
df = cslib.fetch_ts('./cs-train')
# Out:
# ... loading ts data from files

# %%
EDA.plot_summary_all_countries(df)

# %%
EDA.plot_summary_for_country(df, 'united_kingdom')

# %%
revenue_df, purchase_df, total_views_df = EDA.make_tables(df)

# %%
EDA.plot_purchases_for_all_but_united_kingdom(purchase_df)

# %%
import plot_performance

# %%
plot_performance.main()
